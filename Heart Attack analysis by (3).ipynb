# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from pandas.plotting import scatter_matrix
import seaborn as sns
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import Data file

# %%
df =pd.read_csv("C:\\Windows\\heart_attack.csv")

# %% [markdown]
# # Data Description & DTypes

# %%
df.shape
# Out:
# (8763, 26)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    RDG0550   33    Male          200         129/90          48         0
# 1    NMA3851   56  Female          262        159/105          46         1
# 2    TUI5807   19  Female          140        161/109          54         0
# 3    YYT5016   50  Female          163         120/62          53         0
# 4    ZAC5937   89  Female          144        153/110          92         1
#
#    Family History  Smoking  Obesity  Alcohol Consumption  \
# 0               1        1        1                    1
# 1               0        1        0                    0
# 2               1        0        0                    1
# 3               1        1        1                    1
# 4               0        1        0                    1
#
#    Exercise Hours Per Week       Diet  Previous Heart Problems  \
# 0                 7.807690  Unhealthy                        0
# 1                17.297628    Average                        1
# 2                 8.695288    Average                        1
# 3                10.161587    Healthy                        0
# 4                16.436787    Healthy                        1
#
#    Medication Use  Stress Level  Sedentary Hours Per Day  Income        BMI  \
# 0               1             2                 0.138443  184066  30.449815
# 1               0             8                 0.369552  211755  34.973685
# 2               1             3                 8.646334  252203  30.554246
# 3               1             7                 1.107884  121954  35.390265
# 4               0             1                 1.337570  180121  39.575483
#
#    Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# 0             63                                6                    7
# 1            333                                7                    8
# 2            537                                2                   10
# 3            591                                0                    9
# 4            145                                2                    5
#
#      Country      Continent           Hemisphere  Heart Attack Risk
# 0  Argentina  South America  Southern Hemisphere                1.0
# 1    Nigeria         Africa  Northern Hemisphere                1.0
# 2   Thailand           Asia  Northern Hemisphere                0.0
# 3      Spain         Europe  Southern Hemisphere                1.0
# 4    Germany         Europe  Northern Hemisphere                1.0

# %%
df.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8763.000000  8763.000000  8763.000000  8763.000000     8763.000000
# mean     53.707977   259.877211    75.021682     0.652288        0.492982
# std      21.249509    80.863276    20.550948     0.476271        0.499979
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                10.014284
# std       0.304186     0.500026             0.490313                 5.783745
# min       0.000000     0.000000             0.000000                 0.002442
# 25%       1.000000     0.000000             0.000000                 4.981579
# 50%       1.000000     1.000000             1.000000                10.069559
# 75%       1.000000     1.000000             1.000000                15.050018
# max       1.000000     1.000000             1.000000                19.998709
#
#        Previous Heart Problems  Medication Use  Stress Level  \
# count              8763.000000     8763.000000   8763.000000
# mean                  0.495835        0.498345      5.469702
# std                   0.500011        0.500026      2.859622
# min                   0.000000        0.000000      1.000000
# 25%                   0.000000        0.000000      3.000000
# 50%                   0.000000        0.000000      5.000000
# 75%                   1.000000        1.000000      8.000000
# max                   1.000000        1.000000     10.000000
#
#        Sedentary Hours Per Day         Income          BMI  Triglycerides  \
# count              8763.000000    8763.000000  8763.000000    8763.000000
# mean                  5.993690  158263.181901    28.891446     417.677051
# std                   3.466359   80575.190806     6.319181     223.748137
# min                   0.001263   20062.000000    18.002337      30.000000
# 25%                   2.998794   88310.000000    23.422985     225.500000
# 50%                   5.933622  157866.000000    28.768999     417.000000
# 75%                   9.019124  227749.000000    34.324594     612.000000
# max                  11.999313  299954.000000    39.997211     800.000000
#
#        Physical Activity Days Per Week  Sleep Hours Per Day  Heart Attack Risk
# count                      8763.000000          8763.000000        7010.000000
# mean                          3.489672             7.023508           0.357204
# std                           2.282687             1.988473           0.479210
# min                           0.000000             4.000000           0.000000
# 25%                           2.000000             5.000000           0.000000
# 50%                           3.000000             7.000000           0.000000
# 75%                           5.000000             9.000000           1.000000
# max                           7.000000            10.000000           1.000000

# %% [markdown]
# # Data Cleaning

# %%
df.isna().sum()
# Out:
# Patient ID                            0
# Age                                   0
# Sex                                   0
# Cholesterol                           0
# Blood Pressure                        0
# Heart Rate                            0
# Diabetes                              0
# Family History                        0
# Smoking                               0
# Obesity                               0
# Alcohol Consumption                   0
# Exercise Hours Per Week               0
# Diet                                  0
# Previous Heart Problems               0
# Medication Use                        0
# Stress Level                          0
# Sedentary Hours Per Day               0
# Income                                0
# BMI                                   0
# Triglycerides                         0
# Physical Activity Days Per Week       0
# Sleep Hours Per Day                   0
# Country                               0
# Continent                             0
# Hemisphere                            0
# Heart Attack Risk                  1753
# dtype: int64

# %%
df=df.fillna(0)

# %%
df.isna().sum()
# Out:
# Patient ID                         0
# Age                                0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# Heart Attack Risk                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Patient ID                          object
# Age                                  int64
# Sex                                 object
# Cholesterol                          int64
# Blood Pressure                      object
# Heart Rate                           int64
# Diabetes                             int64
# Family History                       int64
# Smoking                              int64
# Obesity                              int64
# Alcohol Consumption                  int64
# Exercise Hours Per Week            float64
# Diet                                object
# Previous Heart Problems              int64
# Medication Use                       int64
# Stress Level                         int64
# Sedentary Hours Per Day            float64
# Income                               int64
# BMI                                float64
# Triglycerides                        int64
# Physical Activity Days Per Week      int64
# Sleep Hours Per Day                  int64
# Country                             object
# Continent                           object
# Hemisphere                          object
# Heart Attack Risk                  float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
#  12  Diet                             8763 non-null   object
#  13  Previous Heart Problems          8763 non-null   int64
#  14  Medication Use                   8763 non-null   int64
#  15  Stress Level                     8763 non-null   int64
#  16  Sedentary Hours Per Day          8763 non-null   float64
#  17  Income                           8763 non-null   int64
#  18  BMI                              8763 non-null   float64
#  19  Triglycerides                    8763 non-null   int64
#  20  Physical Activity Days Per Week  8763 non-null   int64
#  21  Sleep Hours Per Day              8763 non-null   int64
#  22  Country                          8763 non-null   object
#  23  Continent                        8763 non-null   object
#  24  Hemisphere                       8763 non-null   object
#  25  Heart Attack Risk                8763 non-null   float64
# dtypes: float64(4), int64(15), object(7)
# memory usage: 1.7+ MB

# %%
df.corr()
# Out:
# C:\Windows\temp\ipykernel_7176\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                       Age  Cholesterol  Heart Rate  Diabetes  \
# Age                              1.000000    -0.009107   -0.003844 -0.014105
# Cholesterol                     -0.009107     1.000000    0.000315 -0.013428
# Heart Rate                      -0.003844     0.000315    1.000000  0.006764
# Diabetes                        -0.014105    -0.013428    0.006764  1.000000
# Family History                   0.008353    -0.021608   -0.013470 -0.013844
# Smoking                          0.394891     0.016342   -0.012331  0.000527
# Obesity                         -0.008140    -0.014843    0.012725  0.012866
# Alcohol Consumption             -0.006666    -0.007261    0.003459  0.005551
# Exercise Hours Per Week          0.001206     0.021517    0.008276 -0.007014
# Previous Heart Problems          0.000868    -0.006070   -0.004956  0.000867
# Medication Use                   0.000980    -0.000905    0.009244 -0.002656
# Stress Level                     0.018307    -0.024487   -0.004547  0.006719
# Sedentary Hours Per Day          0.017280     0.018914   -0.010232  0.004705
# Income                          -0.001733     0.000007    0.004873 -0.000759
# BMI                             -0.002612     0.017292    0.005299 -0.002852
# Triglycerides                    0.003415    -0.005454    0.012244  0.010431
# Physical Activity Days Per Week  0.001384     0.016056    0.000834 -0.002411
# Sleep Hours Per Day             -0.002185     0.004456    0.001811 -0.012457
# Heart Attack Risk                0.004401     0.017636   -0.001134  0.027406
#
#                                  Family History   Smoking   Obesity  \
# Age                                    0.008353  0.394891 -0.008140
# Cholesterol                           -0.021608  0.016342 -0.014843
# Heart Rate                            -0.013470 -0.012331  0.012725
# Diabetes                              -0.013844  0.000527  0.012866
# Family History                         1.000000  0.011748 -0.001444
# Smoking                                0.011748  1.000000  0.003969
# Obesity                               -0.001444  0.003969  1.000000
# Alcohol Consumption                    0.012701  0.012754 -0.024195
# Exercise Hours Per Week               -0.006378 -0.000150  0.002099
# Previous Heart Problems               -0.004568 -0.000574  0.005159
# Medication Use                         0.000981 -0.010877 -0.006267
# Stress Level                           0.015637 -0.001757  0.010626
# Sedentary Hours Per Day                0.002561  0.015311 -0.001333
# Income                                -0.000401  0.003096 -0.003870
# BMI                                   -0.011492  0.007670 -0.006058
# Triglycerides                         -0.001904  0.004650  0.001467
# Physical Activity Days Per Week        0.009561 -0.006465  0.005337
# Sleep Hours Per Day                   -0.011199 -0.005424 -0.005314
# Heart Attack Risk                     -0.005773 -0.005551 -0.012414
#
#                                  Alcohol Consumption  Exercise Hours Per Week  \
# Age                                        -0.006666                 0.001206
# Cholesterol                                -0.007261                 0.021517
# Heart Rate                                  0.003459                 0.008276
# Diabetes                                    0.005551                -0.007014
# Family History                              0.012701                -0.006378
# Smoking                                     0.012754                -0.000150
# Obesity                                    -0.024195                 0.002099
# Alcohol Consumption                         1.000000                -0.008514
# Exercise Hours Per Week                    -0.008514                 1.000000
# Previous Heart Problems                     0.010395                 0.005253
# Medication Use                              0.003339                -0.007119
# Stress Level                               -0.005023                -0.009102
# Sedentary Hours Per Day                    -0.012828                 0.008756
# Income                                     -0.022396                -0.023414
# BMI                                         0.010562                 0.003777
# Triglycerides                               0.006169                 0.001717
# Physical Activity Days Per Week             0.001593                 0.007725
# Sleep Hours Per Day                        -0.000843                -0.001245
# Heart Attack Risk                          -0.011128                 0.009712
#
#                                  Previous Heart Problems  Medication Use  \
# Age                                             0.000868        0.000980
# Cholesterol                                    -0.006070       -0.000905
# Heart Rate                                     -0.004956        0.009244
# Diabetes                                        0.000867       -0.002656
# Family History                                 -0.004568        0.000981
# Smoking                                        -0.000574       -0.010877
# Obesity                                         0.005159       -0.006267
# Alcohol Consumption                             0.010395        0.003339
# Exercise Hours Per Week                         0.005253       -0.007119
# Previous Heart Problems                         1.000000        0.005336
# Medication Use                                  0.005336        1.000000
# Stress Level                                   -0.017629        0.000863
# Sedentary Hours Per Day                        -0.002694        0.022513
# Income                                         -0.003281       -0.003464
# BMI                                             0.015718        0.009514
# Triglycerides                                  -0.019029       -0.011095
# Physical Activity Days Per Week                 0.008537       -0.011139
# Sleep Hours Per Day                             0.004460       -0.020393
# Heart Attack Risk                               0.014363        0.002093
#
#                                  Stress Level  Sedentary Hours Per Day  \
# Age                                  0.018307                 0.017280
# Cholesterol                         -0.024487                 0.018914
# Heart Rate                          -0.004547                -0.010232
# Diabetes                             0.006719                 0.004705
# Family History                       0.015637                 0.002561
# Smoking                             -0.001757                 0.015311
# Obesity                              0.010626                -0.001333
# Alcohol Consumption                 -0.005023                -0.012828
# Exercise Hours Per Week             -0.009102                 0.008756
# Previous Heart Problems             -0.017629                -0.002694
# Medication Use                       0.000863                 0.022513
# Stress Level                         1.000000                -0.005397
# Sedentary Hours Per Day             -0.005397                 1.000000
# Income                              -0.002760                 0.003511
# BMI                                 -0.003250                -0.000024
# Triglycerides                       -0.003921                -0.005785
# Physical Activity Days Per Week      0.007405                -0.006178
# Sleep Hours Per Day                 -0.014205                 0.004792
# Heart Attack Risk                   -0.003899                -0.001101
#
#                                    Income       BMI  Triglycerides  \
# Age                             -0.001733 -0.002612       0.003415
# Cholesterol                      0.000007  0.017292      -0.005454
# Heart Rate                       0.004873  0.005299       0.012244
# Diabetes                        -0.000759 -0.002852       0.010431
# Family History                  -0.000401 -0.011492      -0.001904
# Smoking                          0.003096  0.007670       0.004650
# Obesity                         -0.003870 -0.006058       0.001467
# Alcohol Consumption             -0.022396  0.010562       0.006169
# Exercise Hours Per Week         -0.023414  0.003777       0.001717
# Previous Heart Problems         -0.003281  0.015718      -0.019029
# Medication Use                  -0.003464  0.009514      -0.011095
# Stress Level                    -0.002760 -0.003250      -0.003921
# Sedentary Hours Per Day          0.003511 -0.000024      -0.005785
# Income                           1.000000  0.008836       0.010739
# BMI                              0.008836  1.000000      -0.005964
# Triglycerides                    0.010739 -0.005964       1.000000
# Physical Activity Days Per Week  0.000130  0.008110      -0.007556
# Sleep Hours Per Day             -0.006598 -0.010030      -0.029216
# Heart Attack Risk                0.009167 -0.001847       0.009255
#
#                                  Physical Activity Days Per Week  \
# Age                                                     0.001384
# Cholesterol                                             0.016056
# Heart Rate                                              0.000834
# Diabetes                                               -0.002411
# Family History                                          0.009561
# Smoking                                                -0.006465
# Obesity                                                 0.005337
# Alcohol Consumption                                     0.001593
# Exercise Hours Per Week                                 0.007725
# Previous Heart Problems                                 0.008537
# Medication Use                                         -0.011139
# Stress Level                                            0.007405
# Sedentary Hours Per Day                                -0.006178
# Income                                                  0.000130
# BMI                                                     0.008110
# Triglycerides                                          -0.007556
# Physical Activity Days Per Week                         1.000000
# Sleep Hours Per Day                                     0.014033
# Heart Attack Risk                                       0.000980
#
#                                  Sleep Hours Per Day  Heart Attack Risk
# Age                                        -0.002185           0.004401
# Cholesterol                                 0.004456           0.017636
# Heart Rate                                  0.001811          -0.001134
# Diabetes                                   -0.012457           0.027406
# Family History                             -0.011199          -0.005773
# Smoking                                    -0.005424          -0.005551
# Obesity                                    -0.005314          -0.012414
# Alcohol Consumption                        -0.000843          -0.011128
# Exercise Hours Per Week                    -0.001245           0.009712
# Previous Heart Problems                     0.004460           0.014363
# Medication Use                             -0.020393           0.002093
# Stress Level                               -0.014205          -0.003899
# Sedentary Hours Per Day                     0.004792          -0.001101
# Income                                     -0.006598           0.009167
# BMI                                        -0.010030          -0.001847
# Triglycerides                              -0.029216           0.009255
# Physical Activity Days Per Week             0.014033           0.000980
# Sleep Hours Per Day                         1.000000          -0.013576
# Heart Attack Risk                          -0.013576           1.000000

# %% [markdown]
# # Data Transformation

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
le = LabelEncoder()
sc= StandardScaler()

# %%
df["Diet"] = le.fit_transform(df["Diet"])
df["Sex"] = le.fit_transform(df["Sex"])

# %%
# Split the values by '/' and calculate the average(adding both values and extracting avg)
df["Blood Pressure"] = df["Blood Pressure"].str.split('/').apply(lambda df: (float(df[0]) + float(df[1])) / 2)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Dropping Unnecessary columns

# %%
x = df.drop(['Patient ID', 'Income', 'Country', 'Continent', 'Hemisphere','Heart Attack Risk'], axis=1)
y = df['Heart Attack Risk']

# %%
x.shape
# Out:
# (8763, 20)

# %%
y.shape
# Out:
# (8763,)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              8763 non-null   int64
#  1   Sex                              8763 non-null   int32
#  2   Cholesterol                      8763 non-null   int64
#  3   Blood Pressure                   8763 non-null   float64
#  4   Heart Rate                       8763 non-null   int64
#  5   Diabetes                         8763 non-null   int64
#  6   Family History                   8763 non-null   int64
#  7   Smoking                          8763 non-null   int64
#  8   Obesity                          8763 non-null   int64
#  9   Alcohol Consumption              8763 non-null   int64
#  10  Exercise Hours Per Week          8763 non-null   float64
#  11  Diet                             8763 non-null   int32
#  12  Previous Heart Problems          8763 non-null   int64
#  13  Medication Use                   8763 non-null   int64
#  14  Stress Level                     8763 non-null   int64
#  15  Sedentary Hours Per Day          8763 non-null   float64
#  16  BMI                              8763 non-null   float64
#  17  Triglycerides                    8763 non-null   int64
#  18  Physical Activity Days Per Week  8763 non-null   int64
#  19  Sleep Hours Per Day              8763 non-null   int64
# dtypes: float64(4), int32(2), int64(14)
# memory usage: 1.3 MB

# %% [markdown]
# # Data Spliting

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.2, random_state = 42)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
x_test.head()
# Out:
#       Age  Sex  Cholesterol  Blood Pressure  Heart Rate  Diabetes  \
# 1226   35    1          222            93.5          67         1
# 7903   20    1          170           110.0          64         1
# 1559   77    1          140           115.5          90         1
# 3621   61    0          227           104.0          91         1
# 7552   49    1          144            95.5          95         1
#
#       Family History  Smoking  Obesity  Alcohol Consumption  \
# 1226               1        1        1                    1
# 7903               1        1        1                    0
# 1559               0        1        0                    1
# 3621               1        1        0                    1
# 7552               1        1        0                    1
#
#       Exercise Hours Per Week  Diet  Previous Heart Problems  Medication Use  \
# 1226                 1.635628     0                        1               0
# 7903                 3.222368     2                        0               0
# 1559                19.108373     0                        1               1
# 3621                19.723129     2                        1               1
# 7552                15.577318     2                        0               1
#
#       Stress Level  Sedentary Hours Per Day        BMI  Triglycerides  \
# 1226            10                11.764951  37.875326            352
# 7903             2                 2.970027  29.004499            797
# 1559             6                 5.634762  23.117767            247
# 3621             9                 1.371171  23.016485            775
# 7552             3                 7.801029  36.509162            564
#
#       Physical Activity Days Per Week  Sleep Hours Per Day
# 1226                                6                    5
# 7903                                7                   10
# 1559                                1                   10
# 3621                                0                    6
# 7552                                6                    8

# %%
x_train.head()
# Out:
#       Age  Sex  Cholesterol  Blood Pressure  Heart Rate  Diabetes  \
# 5967   66    1          307           117.5          72         1
# 8270   69    1          203           101.0          63         1
# 100    62    1          214           120.5          60         1
# 3410   78    0          235            98.0          49         1
# 1790   82    1          226           106.0          93         1
#
#       Family History  Smoking  Obesity  Alcohol Consumption  \
# 5967               0        1        1                    0
# 8270               0        1        1                    0
# 100                1        1        0                    1
# 3410               0        1        1                    1
# 1790               1        1        1                    1
#
#       Exercise Hours Per Week  Diet  Previous Heart Problems  Medication Use  \
# 5967                16.425339     1                        1               1
# 8270                13.935977     1                        0               0
# 100                  6.595610     1                        1               0
# 3410                13.604464     2                        1               1
# 1790                 9.420146     0                        0               0
#
#       Stress Level  Sedentary Hours Per Day        BMI  Triglycerides  \
# 5967             6                 1.290549  20.262038            139
# 8270             5                11.528806  37.324755            749
# 100              1                 4.524719  28.655940            673
# 3410             4                 6.061124  27.436883            479
# 1790             8                 7.859264  35.779210            741
#
#       Physical Activity Days Per Week  Sleep Hours Per Day
# 5967                                0                    6
# 8270                                5                    7
# 100                                 7                    8
# 3410                                3                    5
# 1790                                6                   10

# %%
y_train.head()
# Out:
# 5967    1.0
# 8270    0.0
# 100     0.0
# 3410    1.0
# 1790    1.0
# Name: Heart Attack Risk, dtype: float64

# %%
x_train.dtypes
# Out:
# Age                                  int64
# Sex                                  int32
# Cholesterol                          int64
# Blood Pressure                     float64
# Heart Rate                           int64
# Diabetes                             int64
# Family History                       int64
# Smoking                              int64
# Obesity                              int64
# Alcohol Consumption                  int64
# Exercise Hours Per Week            float64
# Diet                                 int32
# Previous Heart Problems              int64
# Medication Use                       int64
# Stress Level                         int64
# Sedentary Hours Per Day            float64
# BMI                                float64
# Triglycerides                        int64
# Physical Activity Days Per Week      int64
# Sleep Hours Per Day                  int64
# dtype: object

# %% [markdown]
# # 1 DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
dt = DecisionTreeClassifier(random_state=42)
# Assuming you have preprocessed data and split it into training and validation sets

dt.fit(x_train, y_train)  # Train the KNN model

# Make predictions on the validation set
dt_predictions = dt.predict(x_test)

# Calculate Accuracy
accuracy = accuracy_score(y_test, dt_predictions)

print("Decision Tree Accuracy:", accuracy*100)
# Out:
# Decision Tree Accuracy: 58.756417569880206

# %% [markdown]
# # 2 Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
clf = DecisionTreeRegressor()
# Assuming you have preprocessed data and split it into training and validation sets

clf.fit(x_train, y_train)  # Train the KNN model

# Make predictions on the validation set
clf_predictions = clf.predict(x_test)

# Calculate Accuracy
clf_accuracy = accuracy_score(y_test, clf_predictions)

print("Decision Tree Accuracy:", accuracy*100)
# Out:
# Decision Tree Accuracy: 58.756417569880206

# %% [markdown]
# # 3 Naive_Bayes (GaussianNB)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

# Assuming you have preprocessed data and split it into training and testing sets
gnb = GaussianNB()
gnb.fit(x_train, y_train)  # Train the Gaussian Naive Bayes model

# Make predictions on the test set
gnb_predictions = gnb.predict(x_test)

# Calculate Accuracy
accuracy = accuracy_score(y_test, gnb_predictions)
print("Naive Bayes Accuracy:", accuracy)

# Display a classification report for more detailed evaluation
print(classification_report(y_test, gnb_predictions))
# Out:
# Naive Bayes Accuracy: 0.710781517398745
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83      1246
#          1.0       0.00      0.00      0.00       507
#
#     accuracy                           0.71      1753
#    macro avg       0.36      0.50      0.42      1753
# weighted avg       0.51      0.71      0.59      1753
# C:\Users\deepakhdfcgfxncv\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\deepakhdfcgfxncv\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\deepakhdfcgfxncv\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("accuracy is ",accuracy*100,"%")
# Out:
# accuracy is  71.0781517398745 %

# %% [markdown]
# # 4 LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\deepakhdfcgfxncv\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=lr.predict(x_test)

# %%
pred[0:5]
# Out:
# array([0., 0., 0., 0., 0.])

# %%
y_test[0:5]
# Out:
# 1226    0.0
# 7903    0.0
# 1559    0.0
# 3621    1.0
# 7552    0.0
# Name: Heart Attack Risk, dtype: float64

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,auc

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[1246    0]
#  [ 507    0]]

# %%
y_test.shape
# Out:
# (1753,)

# %%
lr.score(x_train,y_train) #Training accuracy
# Out:
# 0.7151212553495007

# %%
print(accuracy_score(pred,y_test)*100) # testing accuracy
# Out:
# 71.0781517398745

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      1.00      0.83      1246
#          1.0       0.00      0.00      0.00       507
#
#     accuracy                           0.71      1753
#    macro avg       0.36      0.50      0.42      1753
# weighted avg       0.51      0.71      0.59      1753
# C:\Users\deepakhdfcgfxncv\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\deepakhdfcgfxncv\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\deepakhdfcgfxncv\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 5 Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier

# Assuming you have preprocessed data and split it into training and validation sets
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)  # You can adjust the number of trees (n_estimators)

# Train the Random Forest model
random_forest.fit(x_train, y_train)

# Make predictions on the test set
rf_predictions = random_forest.predict(x_test)
accuracy = accuracy_score(y_test, rf_predictions)

# Print the Accuracy
print("Random Forest Accuracy:", accuracy * 100)
# Out:
# Random Forest Accuracy: 71.02110667427267
